# %% [markdown]
# ## Impute missing values of session attributes based on label

# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split

# %%
np.random.seed(1)

# %%
data = pd.read_csv("./data/df_all_inc_sess.csv")
y = pd.read_csv("./data/y.csv")

# %%
# drop last 15 samples as they're caused by a bug (https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/forums/t/17737/announcement-competition-will-restart-shortly)
X = data[0:213466]
X = X[0:213451]
y = y[0:213451]

# %%
print X.shape
print y.shape
# Out:
# (213451, 771)
# (213451, 1)

# %%
X.country_destination = y.country_destination

# %%
# train / test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=1)

# %%
X_train.country_destination = y_train.country_destination

# %% [markdown]
# ## IMPUTE W ALL DATA AVAILABLE

# %%
# impute w all data available
countries = ['FR', 'NL', 'PT', 'CA', 'DE', 'IT', 'US', 'NDF', 'other', 'AU', 'GB', 'ES']
# index: 221; col_name: action_lookup
# index: 767; col_name: num_sessions_24_hrs
for i in range(221,771):   
    col_name = X.columns[i] 
    print "Processing %s (%d/%d)" % (col_name, i-220, 768-221)
    for country in countries:
        country_value_counts = X[(X.country_destination == country) & (X[col_name].notnull())][col_name].value_counts()
        #print "country_value_counts:\n%s" % country_value_counts
        country_values = list(country_value_counts.index)
        #print "country_values:\n%s" % country_values
        country_value_probas = [val/float(sum(country_value_counts.values)) for val in country_value_counts.values]
        #print "country_value_probas:\n%s" % country_value_probas
        
        x = X[(X.country_destination == country) & (X[col_name].isnull())]
        #print "x:\n%s" % x
        #print "x.index:\n%s" % x.index
        #print "X.loc[x.index, [col_name]] (before):\n%s" % X.loc[x.index, [col_name]]
        X.loc[x.index, [col_name]] = np.random.choice(country_values, len(x.index), p=country_value_probas)
        #print "X.loc[x.index, [col_name]] (after):\n%s" % np.random.choice(country_values, len(x.index), p=country_value_probas)
# Out:
# Processing device_type_Blackberry (538/547)
# Processing device_type_iPodtouch (539/547)
# Processing device_type_Windows Phone (540/547)
# Processing device_type_Opera Phone (541/547)
# Processing num_sessions_1_hrs (542/547)
# Processing num_sessions_2_hrs (543/547)
# Processing num_sessions_4_hrs (544/547)
# Processing num_sessions_8_hrs (545/547)
# Processing num_sessions_16_hrs (546/547)
# Processing num_sessions_24_hrs (547/547)
# Processing secs_elapsed (548/547)
# Processing hit_count (549/547)
# Processing avg_secs_elapsed (550/547)

# %% [markdown]
# ## IMPUTE W TRAIN SET ONLY (DON'T CHEAT|OVERFIT !)

# %%
# impute w all data available
countries = ['FR', 'NL', 'PT', 'CA', 'DE', 'IT', 'US', 'NDF', 'other', 'AU', 'GB', 'ES']
# index: 221; col_name: action_lookup
# index: 767; col_name: num_sessions_24_hrs
for i in range(221,771):   
    col_name = X.columns[i] 
    print "Processing %s (%d/%d)" % (col_name, i-220, 768-221)
    for country in countries:
        country_value_counts = X_train[(X_train.country_destination == country) & (X_train[col_name].notnull())][col_name].value_counts()
        #print "country_value_counts:\n%s" % country_value_counts
        country_values = list(country_value_counts.index)
        #print "country_values:\n%s" % country_values
        country_value_probas = [val/float(sum(country_value_counts.values)) for val in country_value_counts.values]
        #print "country_value_probas:\n%s" % country_value_probas
        
        x = X[(X.country_destination == country) & (X[col_name].isnull())]
        #print "x:\n%s" % x
        #print "x.index:\n%s" % x.index
        #print "X.loc[x.index, [col_name]] (before):\n%s" % X.loc[x.index, [col_name]]
        X.loc[x.index, [col_name]] = np.random.choice(country_values, len(x.index), p=country_value_probas)
        #print "X.loc[x.index, [col_name]] (after):\n%s" % np.random.choice(country_values, len(x.index), p=country_value_probas)
# Out:
# Processing action_lookup (1/547)
# Processing action_search_results (2/547)
# Processing action_personalize (3/547)
# Processing action_index (4/547)
# Processing action_similar_listings (5/547)
# Processing action_ajax_refresh_subtotal (6/547)
# Processing action_show (7/547)
# Processing action_header_userpic (8/547)
# Processing action_ask_question (9/547)
# Processing action_ (10/547)
# Processing action_other_hosting_reviews_first (11/547)
# Processing action_hosting_social_proof (12/547)
# Processing action_decision_tree (13/547)
# Processing action_recent_reservations (14/547)
# Processing action_faq_experiment_ids (15/547)
# Processing action_multi (16/547)
# Processing action_active (17/547)
# Processing action_dashboard (18/547)
# Processing action_create (19/547)
# Processing action_confirm_email (20/547)
# Processing action_show_personalize (21/547)
# Processing action_verify (22/547)
# Processing action_pending (23/547)
# Processing action_requested (24/547)
# Processing action_concierge (25/547)
# Processing action_faq (26/547)
# Processing action_clear_reservation (27/547)
# Processing action_cancellation_policies (28/547)
# Processing action_track_page_view (29/547)
# Processing action_update (30/547)
# Processing action_my (31/547)
# Processing action_campaigns (32/547)
# Processing action_notifications (33/547)
# Processing action_listings (34/547)
# Processing action_unavailabilities (35/547)
# Processing action_ajax_lwlb_contact (36/547)
# Processing action_ajax_check_dates (37/547)
# Processing action_qt2 (38/547)
# Processing action_request_new_confirm_email (39/547)
# Processing action_ajax_photo_widget_form_iframe (40/547)
# Processing action_facebook_auto_login (41/547)
# Processing action_identity (42/547)
# Processing action_qt_reply_v2 (43/547)
# Processing action_travel_plans_current (44/547)
# Processing action_complete_status (45/547)
# Processing action_populate_from_facebook (46/547)
# Processing action_kba_update (47/547)
# Processing action_kba (48/547)
# Processing action_login (49/547)
# Processing action_authenticate (50/547)
# Processing action_calendar_tab_inner2 (51/547)
# Processing action_other_hosting_reviews (52/547)
# Processing action_social_connections (53/547)
# Processing action_relationship (54/547)
# Processing action_15 (55/547)
# Processing action_collections (56/547)
# Processing action_12 (57/547)
# Processing action_jumio_redirect (58/547)
# Processing action_jumio_token (59/547)
# Processing action_login_modal (60/547)
# Processing action_domains (61/547)
# Processing action_toggle_archived_thread (62/547)
# Processing action_search (63/547)
# Processing action_edit_verification (64/547)
# Processing action_edit (65/547)
# Processing action_ajax_ldp (66/547)
# Processing action_connect (67/547)
# Processing action_account (68/547)
# Processing action_delete (69/547)
# Processing action_phone_number_widget (70/547)
# Processing action_callback (71/547)
# Processing action_signup_modal (72/547)
# Processing action_10 (73/547)
# Processing action_open_graph_setting (74/547)
# Processing action_reviews (75/547)
# Processing action_signup_login (76/547)
# Processing action_payment_instruments (77/547)
# Processing action_payment_methods (78/547)
# Processing action_pay (79/547)
# Processing action_unread (80/547)
# Processing action_at_checkpoint (81/547)
# Processing action_push_notification_callback (82/547)
# Processing action_faq_category (83/547)
# Processing action_localization_settings (84/547)
# Processing action_update_notifications (85/547)
# Processing action_manage_listing (86/547)
# Processing action_set_user (87/547)
# Processing action_references (88/547)
# Processing action_languages_multiselect (89/547)
# Processing action_salute (90/547)
# Processing action_rentals (91/547)
# Processing action_currencies (92/547)
# Processing action_new (93/547)
# Processing action_position (94/547)
# Processing action_populate_help_dropdown (95/547)
# Processing action_popular (96/547)
# Processing action_popular_listing (97/547)
# Processing action_listing (98/547)
# Processing action_available (99/547)
# Processing action_glob (100/547)
# Processing action_this_hosting_reviews (101/547)
# Processing action_widget (102/547)
# Processing action_complete (103/547)
# Processing action_profile_pic (104/547)
# Processing action_signature (105/547)
# Processing action_apply_reservation (106/547)
# Processing action_ajax_statsd (107/547)
# Processing action_travel (108/547)
# Processing action_tos_confirm (109/547)
# Processing action_uptodate (110/547)
# Processing action_ajax_payout_options_by_country (111/547)
# Processing action_payout_preferences (112/547)
# Processing action_payout_update (113/547)
# Processing action_ajax_payout_edit (114/547)
# Processing action_pending_tickets (115/547)
# Processing action_issue (116/547)
# Processing action_contact_new (117/547)
# Processing action_itinerary (118/547)
# Processing action_receipt (119/547)
# Processing action_update_hide_from_search_engines (120/547)
# Processing action_settings (121/547)
# Processing action_privacy (122/547)
# Processing action_reviews_new (123/547)
# Processing action_add_guests (124/547)
# Processing action_ajax_image_upload (125/547)
# Processing action_qt_with (126/547)
# Processing action_webcam_upload (127/547)
# Processing action_friends (128/547)
# Processing action_ajax_google_translate_description (129/547)
# Processing action_trust (130/547)
# Processing action_guarantee (131/547)
# Processing action_supported (132/547)
# Processing action_countries (133/547)
# Processing action_status (134/547)
# Processing action_upload (135/547)
# Processing action_authorize (136/547)
# Processing action_rate (137/547)
# Processing action_remove_dashboard_alert (138/547)
# Processing action_ajax_get_results (139/547)
# Processing action_recommend (140/547)
# Processing action_change_currency (141/547)
# Processing action_transaction_history_paginated (142/547)
# Processing action_transaction_history (143/547)
# Processing action_set_password (144/547)
# Processing action_cancel (145/547)
# Processing action_phone_verification_modal (146/547)
# Processing action_submit_contact (147/547)
# Processing action_detect_fb_session (148/547)
# Processing action_tell_a_friend (149/547)
# Processing action_change (150/547)
# Processing action_clickthrough (151/547)
# Processing action_multi_message_attributes (152/547)
# Processing action_update_friends_display (153/547)
# Processing action_my_listings (154/547)
# Processing action_email_itinerary_colorbox (155/547)
# Processing action_mobile_landing_page (156/547)
# Processing action_create_ach (157/547)
# Processing action_country_options (158/547)
# Processing action_11 (159/547)
# Processing action_host_2013 (160/547)
# Processing action_terms (161/547)
# Processing action_multi_message (162/547)
# Processing action_ajax_send_message (163/547)
# Processing action_airbnb_picks (164/547)
# Processing action_friends_new (165/547)
# Processing action_reputation (166/547)
# Processing action_complete_redirect (167/547)
# Processing action_toggle_starred_thread (168/547)
# Processing action_email_share (169/547)
# Processing action_email_wishlist (170/547)
# Processing action_destroy (171/547)
# Processing action_add_note (172/547)
# Processing action_overview (173/547)
# Processing action_requirements (174/547)
# Processing action_update_reservation_requirements (175/547)
# Processing action_image_order (176/547)
# Processing action_review_page (177/547)
# Processing action_ajax_worth (178/547)
# Processing action_place_worth (179/547)
# Processing action_google_importer (180/547)
# Processing action_change_availability (181/547)
# Processing action_hospitality (182/547)
# Processing action_change_password (183/547)
# Processing action_feed (184/547)
# Processing action_host_summary (185/547)
# Processing action_ajax_price_and_availability (186/547)
# Processing action_jumio (187/547)
# Processing action_guest_booked_elsewhere (188/547)
# Processing action_about_us (189/547)
# Processing action_founders (190/547)
# Processing action_travel_plans_previous (191/547)
# Processing action_why_host (192/547)
# Processing action_hospitality_standards (193/547)
# Processing action_social (194/547)
# Processing action_recommendations (195/547)
# Processing action_update_cached (196/547)
# Processing action_become_user (197/547)
# Processing action_departments (198/547)
# Processing action_department (199/547)
# Processing action_office_location (200/547)
# Processing action_photography (201/547)
# Processing action_preapproval (202/547)
# Processing action_maybe_information (203/547)
# Processing action_toggle_availability (204/547)
# Processing action_payoneer_account_redirect (205/547)
# Processing action_forgot_password (206/547)
# Processing action_new_host (207/547)
# Processing action_payoneer_signup_complete (208/547)
# Processing action_ajax_google_translate (209/547)
# Processing action_onenight (210/547)
# Processing action_approve (211/547)
# Processing action_nyan (212/547)
# Processing action_booking (213/547)
# Processing action_payout_delete (214/547)
# Processing action_change_default_payout (215/547)
# Processing action_envoy_bank_details_redirect (216/547)
# Processing action_respond (217/547)
# Processing action_request_photography (218/547)
# Processing action_zendesk_login_jwt (219/547)
# Processing action_ajax_photo_widget (220/547)
# Processing action_message (221/547)
# Processing action_southern-europe (222/547)
# Processing action_life (223/547)
# Processing action_press_release (224/547)
# Processing action_media_resources (225/547)
# Processing action_press_news (226/547)
# Processing action_referrer_status (227/547)
# Processing action_create_multiple (228/547)
# Processing action_load_more (229/547)
# Processing action_create_paypal (230/547)
# Processing action_locale_from_host (231/547)
# Processing action_terms_and_conditions (232/547)
# Processing action_invalid_action (233/547)
# Processing action_photography_update (234/547)
# Processing action_badge (235/547)
# Processing action_apply (236/547)
# Processing action_redirect (237/547)
# Processing action_pricing (238/547)
# Processing action_apply_code (239/547)
# Processing action_slideshow (240/547)
# Processing action_locations (241/547)
# Processing action_ajax_google_translate_reviews (242/547)
# Processing action_new_session (243/547)
# Processing action_has_profile_pic (244/547)
# Processing action_sublets (245/547)
# Processing action_wishlists (246/547)
# Processing action_reservation (247/547)
# Processing action_localized (248/547)
# Processing action_home_safety_landing (249/547)
# Processing action_click (250/547)
# Processing action_how_it_works (251/547)
# Processing action_ajax_get_referrals_amt (252/547)
# Processing action_phone_verification (253/547)
# Processing action_satisfy (254/547)
# Processing action_city_count (255/547)
# Processing action_recommendation_page (256/547)
# Processing action_press_content (257/547)
# Processing action_guest_billing_receipt (258/547)
# Processing action_ajax_payout_split_edit (259/547)
# Processing action_print_confirmation (260/547)
# Processing action_envoy_form (261/547)
# Processing action_ajax_special_offer_dates_available (262/547)
# Processing action_ajax_referral_banner_experiment_type (263/547)
# Processing action_patch (264/547)
# Processing action_questions (265/547)
# Processing action_home_safety_terms (266/547)
# Processing action_track_activity (267/547)
# Processing action_check (268/547)
# Processing action_sldf (269/547)
# Processing action_recommended_listings (270/547)
# Processing action_mobile_oauth_callback (271/547)
# Processing action_show_code (272/547)
# Processing action_signed_out_modal (273/547)
# Processing action_plaxo_cb (274/547)
# Processing action_views (275/547)
# Processing action_friend_listing (276/547)
# Processing action_ajax_referral_banner_type (277/547)
# Processing action_deactivate (278/547)
# Processing action_sync (279/547)
# Processing action_social-media (280/547)
# Processing action_united-states (281/547)
# Processing action_email_by_key (282/547)
# Processing action_disaster_action (283/547)
# Processing action_views_campaign (284/547)
# Processing action_update_message (285/547)
# Processing action_spoken_languages (286/547)
# Processing action_use_mobile_site (287/547)
# Processing action_deauthorize (288/547)
# Processing action_special_offer (289/547)
# Processing action_top_destinations (290/547)
# Processing action_create_airbnb (291/547)
# Processing action_handle_vanity_url (292/547)
# Processing action_impressions (293/547)
# Processing action_message_to_host_focus (294/547)
# Processing action_cancellation_policy_click (295/547)
# Processing action_message_to_host_change (296/547)
# Processing action_agree_terms_check (297/547)
# Processing action_read_policy_click (298/547)
# Processing action_phone_verification_success (299/547)
# Processing action_phone_verification_number_sucessfully_submitted (300/547)
# Processing action_phone_verification_number_submitted_for_sms (301/547)
# Processing action_phone_verification_phone_number_removed (302/547)
# Processing action_endpoint_error (303/547)
# Processing action_p4_refund_policy_terms (304/547)
# Processing action_apply_coupon_error_type (305/547)
# Processing action_apply_coupon_error (306/547)
# Processing action_apply_coupon_click (307/547)
# Processing action_coupon_field_focus (308/547)
# Processing action_coupon_code_click (309/547)
# Processing action_agree_terms_uncheck (310/547)
# Processing action_p4_terms (311/547)
# Processing action_phone_verification_call_taking_too_long (312/547)
# Processing action_phone_verification_number_submitted_for_call (313/547)
# Processing action_phone_verification_error (314/547)
# Processing action_apply_coupon_click_success (315/547)
# Processing action_set_default (316/547)
# Processing action_update_country_of_residence (317/547)
# Processing action_open_hard_fallback_modal (318/547)
# Processing action_tos_2014 (319/547)
# Processing action_views_campaign_rules (320/547)
# Processing action_weibo_signup_referral_finish (321/547)
# Processing action_signup_weibo_referral (322/547)
# Processing action_similar_listings_v2 (323/547)
# Processing action_confirmation (324/547)
# Processing action_signup_weibo (325/547)
# Processing action_acculynk_load_pin_pad (326/547)
# Processing action_acculynk_bin_check_success (327/547)
# Processing action_acculynk_session_obtained (328/547)
# Processing action_acculynk_pin_pad_inactive (329/547)
# Processing action_reactivate (330/547)
# Processing action_airbrb (331/547)
# Processing action_desks (332/547)
# Processing action_sandy (333/547)
# Processing action_unsubscribe (334/547)
# Processing action_host_cancel (335/547)
# Processing action_acculynk_bin_check_failed (336/547)
# Processing action_acculynk_pin_pad_error (337/547)
# Processing action_custom_recommended_destinations (338/547)
# Processing action_this_hosting_reviews_3000 (339/547)
# Processing action_reset_calendar (340/547)
# Processing action_events (341/547)
# Processing action_business_travel (342/547)
# Processing action_add_guest_colorbox (343/547)
# Processing action_hard_fallback_submit (344/547)
# Processing action_add_business_address_colorbox (345/547)
# Processing action_my_reservations (346/547)
# Processing action_report (347/547)
# Processing action_book (348/547)
# Processing action_revert_to_admin (349/547)
# Processing action_acculynk_pin_pad_success (350/547)
# Processing action_south-america (351/547)
# Processing action_braintree_client_token (352/547)
# Processing action_view (353/547)
# Processing action_stpcv (354/547)
# Processing action_set_minimum_payout_amount (355/547)
# Processing action_support_phone_numbers (356/547)
# Processing action_refund_guest_cancellation (357/547)
# Processing action_accept_decline (358/547)
# Processing action_deactivated (359/547)
# Processing action_rest-of-world (360/547)
# Processing action_type_ (361/547)
# Processing action_type_click (362/547)
# Processing action_type_data (363/547)
# Processing action_type_view (364/547)
# Processing action_type_submit (365/547)
# Processing action_type_message_post (366/547)
# Processing action_type_-unknown- (367/547)
# Processing action_type_booking_request (368/547)
# Processing action_type_partner_callback (369/547)
# Processing action_type_booking_response (370/547)
# Processing action_type_modify (371/547)
# Processing action_detail_ (372/547)
# Processing action_detail_view_search_results (373/547)
# Processing action_detail_wishlist_content_update (374/547)
# Processing action_detail_similar_listings (375/547)
# Processing action_detail_change_trip_characteristics (376/547)
# Processing action_detail_p3 (377/547)
# Processing action_detail_header_userpic (378/547)
# Processing action_detail_contact_host (379/547)
# Processing action_detail_message_post (380/547)
# Processing action_detail_-unknown- (381/547)
# Processing action_detail_dashboard (382/547)
# Processing action_detail_create_user (383/547)
# Processing action_detail_confirm_email_link (384/547)
# Processing action_detail_user_profile_content_update (385/547)
# Processing action_detail_user_profile (386/547)
# Processing action_detail_pending (387/547)
# Processing action_detail_p5 (388/547)
# Processing action_detail_create_phone_numbers (389/547)
# Processing action_detail_cancellation_policies (390/547)
# Processing action_detail_user_wishlists (391/547)
# Processing action_detail_change_contact_host_dates (392/547)
# Processing action_detail_wishlist (393/547)
# Processing action_detail_message_thread (394/547)
# Processing action_detail_request_new_confirm_email (395/547)
# Processing action_detail_send_message (396/547)
# Processing action_detail_your_trips (397/547)
# Processing action_detail_login_page (398/547)
# Processing action_detail_login (399/547)
# Processing action_detail_login_modal (400/547)
# Processing action_detail_toggle_archived_thread (401/547)
# Processing action_detail_p1 (402/547)
# Processing action_detail_profile_verifications (403/547)
# Processing action_detail_edit_profile (404/547)
# Processing action_detail_oauth_login (405/547)
# Processing action_detail_post_checkout_action (406/547)
# Processing action_detail_account_notification_settings (407/547)
# Processing action_detail_update_user_profile (408/547)
# Processing action_detail_oauth_response (409/547)
# Processing action_detail_signup_modal (410/547)
# Processing action_detail_signup_login_page (411/547)
# Processing action_detail_at_checkpoint (412/547)
# Processing action_detail_manage_listing (413/547)
# Processing action_detail_create_listing (414/547)
# Processing action_detail_your_listings (415/547)
# Processing action_detail_profile_references (416/547)
# Processing action_detail_list_your_space (417/547)
# Processing action_detail_popular_wishlists (418/547)
# Processing action_detail_listing_reviews_page (419/547)
# Processing action_detail_apply_coupon (420/547)
# Processing action_detail_user_tax_forms (421/547)
# Processing action_detail_account_payout_preferences (422/547)
# Processing action_detail_guest_itinerary (423/547)
# Processing action_detail_guest_receipt (424/547)
# Processing action_detail_account_privacy_settings (425/547)
# Processing action_detail_lookup_message_thread (426/547)
# Processing action_detail_friends_wishlists (427/547)
# Processing action_detail_host_guarantee (428/547)
# Processing action_detail_delete_phone_numbers (429/547)
# Processing action_detail_account_transaction_history (430/547)
# Processing action_detail_set_password (431/547)
# Processing action_detail_guest_cancellation (432/547)
# Processing action_detail_change_or_alter (433/547)
# Processing action_detail_your_reservations (434/547)
# Processing action_detail_terms_and_privacy (435/547)
# Processing action_detail_airbnb_picks_wishlists (436/547)
# Processing action_detail_toggle_starred_thread (437/547)
# Processing action_detail_email_wishlist (438/547)
# Processing action_detail_email_wishlist_button (439/547)
# Processing action_detail_wishlist_note (440/547)
# Processing action_detail_calculate_worth (441/547)
# Processing action_detail_place_worth (442/547)
# Processing action_detail_change_password (443/547)
# Processing action_detail_alteration_field (444/547)
# Processing action_detail_previous_trips (445/547)
# Processing action_detail_update_listing (446/547)
# Processing action_detail_update_listing_description (447/547)
# Processing action_detail_user_reviews (448/547)
# Processing action_detail_update_user (449/547)
# Processing action_detail_notifications (450/547)
# Processing action_detail_user_social_connections (451/547)
# Processing action_detail_unavailable_dates (452/547)
# Processing action_detail_reservations (453/547)
# Processing action_detail_listing_reviews (454/547)
# Processing action_detail_user_listings (455/547)
# Processing action_detail_signup (456/547)
# Processing action_detail_message_inbox (457/547)
# Processing action_detail_trip_availability (458/547)
# Processing action_detail_payment_instruments (459/547)
# Processing action_detail_admin_templates (460/547)
# Processing action_detail_host_home (461/547)
# Processing action_detail_translations (462/547)
# Processing action_detail_forgot_password (463/547)
# Processing action_detail_homepage (464/547)
# Processing action_detail_remove_dashboard_alert (465/547)
# Processing action_detail_user_friend_recommendations (466/547)
# Processing action_detail_confirm_email (467/547)
# Processing action_detail_host_respond (468/547)
# Processing action_detail_booking (469/547)
# Processing action_detail_respond_to_alteration_request (470/547)
# Processing action_detail_alteration_request (471/547)
# Processing action_detail_create_alteration_request (472/547)
# Processing action_detail_delete_listing (473/547)
# Processing action_detail_set_password_page (474/547)
# Processing action_detail_delete_listing_description (475/547)
# Processing action_detail_translate_listing_reviews (476/547)
# Processing action_detail_book_it (477/547)
# Processing action_detail_instant_book (478/547)
# Processing action_detail_request_to_book (479/547)
# Processing action_detail_complete_booking (480/547)
# Processing action_detail_change_availability (481/547)
# Processing action_detail_special_offer_field (482/547)
# Processing action_detail_listing_recommendations (483/547)
# Processing action_detail_view_listing (484/547)
# Processing action_detail_listing_descriptions (485/547)
# Processing action_detail_user_languages (486/547)
# Processing action_detail_p4 (487/547)
# Processing action_detail_message_to_host_focus (488/547)
# Processing action_detail_cancellation_policy_click (489/547)
# Processing action_detail_message_to_host_change (490/547)
# Processing action_detail_read_policy_click (491/547)
# Processing action_detail_phone_verification_success (492/547)
# Processing action_detail_p4_refund_policy_terms (493/547)
# Processing action_detail_apply_coupon_error (494/547)
# Processing action_detail_apply_coupon_click (495/547)
# Processing action_detail_coupon_field_focus (496/547)
# Processing action_detail_coupon_code_click (497/547)
# Processing action_detail_p4_terms (498/547)
# Processing action_detail_apply_coupon_click_success (499/547)
# Processing action_detail_tos_2014 (500/547)
# Processing action_detail_view_reservations (501/547)
# Processing action_detail_view_locations (502/547)
# Processing action_detail_modify_users (503/547)
# Processing action_detail_view_security_checks (504/547)
# Processing action_detail_phone_numbers (505/547)
# Processing action_detail_profile_reviews (506/547)
# Processing action_detail_modify_reservations (507/547)
# Processing action_detail_view_resolutions (508/547)
# Processing action_detail_account_payment_methods (509/547)
# Processing action_detail_create_payment_instrument (510/547)
# Processing action_detail_set_default_payment_instrument (511/547)
# Processing action_detail_delete_payment_instrument (512/547)
# Processing action_detail_photos (513/547)
# Processing action_detail_click_reviews (514/547)
# Processing action_detail_move_map (515/547)
# Processing action_detail_share (516/547)
# Processing action_detail_cancellation_policy (517/547)
# Processing action_detail_click_about_host (518/547)
# Processing action_detail_click_amenities (519/547)
# Processing action_detail_host_refund_guest (520/547)
# Processing action_detail_host_respond_page (521/547)
# Processing action_detail_view_user_real_names (522/547)
# Processing action_detail_view_identity_verifications (523/547)
# Processing action_detail_view_ghosting_reasons (524/547)
# Processing action_detail_view_ghostings (525/547)
# Processing action_detail_host_standard_suspension (526/547)
# Processing action_detail_deactivate_user_account (527/547)
# Processing device_type_Windows Desktop (528/547)
# Processing device_type_-unknown- (529/547)
# Processing device_type_Mac Desktop (530/547)
# Processing device_type_Android Phone (531/547)
# Processing device_type_iPhone (532/547)
# Processing device_type_iPad Tablet (533/547)
# Processing device_type_Android App Unknown Phone/Tablet (534/547)
# Processing device_type_Linux Desktop (535/547)
# Processing device_type_Tablet (536/547)
# Processing device_type_Chromebook (537/547)
# Processing device_type_Blackberry (538/547)
# Processing device_type_iPodtouch (539/547)
# Processing device_type_Windows Phone (540/547)
# Processing device_type_Opera Phone (541/547)
# Processing num_sessions_1_hrs (542/547)
# Processing num_sessions_2_hrs (543/547)
# Processing num_sessions_4_hrs (544/547)
# Processing num_sessions_8_hrs (545/547)
# Processing num_sessions_16_hrs (546/547)
# Processing num_sessions_24_hrs (547/547)
# Processing secs_elapsed (548/547)
# Processing hit_count (549/547)
# Processing avg_secs_elapsed (550/547)

# %%
def_all_inc_sess_imputed = X.append(data[213466:], ignore_index=True)

# %%
def_all_inc_sess_imputed.shape
# Out:
# (275547, 771)

# %%
def_all_inc_sess_imputed.to_csv('./data/df_all_inc_sess_imputed_w_train_data_only.csv', index=False)

# %%
# y w 213451 rows (last 15 buggy samples dropped is saved)
y.to_csv("./data/y_2.csv", index=False) #
